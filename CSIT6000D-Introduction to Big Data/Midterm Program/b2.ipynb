# %%
listoflist=[]         
with open('/Users/jiefenghou/Documents/bbcsport/bbcsport.mtx') as f:
    next(f)
    next(f)
    for i in f:
        list=[]
        i=i.strip('\n')
        list.append(i.split(' ')[0])
        list.append(i.split(' ')[1])
        list.append(i.split(' ')[2])
        listoflist.append(list)

    dict={}
    for list in listoflist:
        if not int(list[1]) in dict:
            dict[int(list[1])] = [int(list[0])]
        else:
            dict[int(list[1])].append(int(list[0]))
                    
    #r=4613
    r= 4613
    # c is prime number which is slightly bigger than the r
    c= 4621
    #number of hash function
    num = 50
    print ("r = {0}, c = {1}, and number = {2}".format(r,c,num))
    
    import random
    randomList=[]
    count = num
    while count > 0:
        randomIndex = random.randint(0,r)           
        if randomIndex in randomList:
            continue
        randomList.append(randomIndex)
        count = count-1
    a=randomList

    randomList=[]
    count = num
    while count > 0:
        randomIndex = random.randint(0,r)           
        if randomIndex in randomList:
            continue
        randomList.append(randomIndex)
        count = count-1
    b=randomList
   
    results=[]
    for key in sorted(dict.keys()):
        result=[]
        for i in range(0,num):   
            miniHash = c+1
            for value in dict[key]:
                hash = (a[i]*value+b[i])%c
                if hash < miniHash:
                    miniHash = hash
            result.append(miniHash)
        results.append(result)
   
    list=dict.keys()
    for index in range(len(list)):
        result1 = results[index]
        for key in range(index+1,len(list)):
            result2 = results[key]
            count=0
            for k in range(0,num):
                if(result1[k] == result2[k]):
                    count=count+1
            score = count/float(num)
            if(score>=0.5):
                print ("B2: Match Document1 ID:{0}, Document2 ID:{1}, Similarity:{2}".format(index+1,key+1,score))
# Out:
# r = 4613, c = 4621, and number = 50
# B2: Match Document1 ID:12, Document2 ID:20, Similarity:1.0
# B2: Match Document1 ID:23, Document2 ID:48, Similarity:0.58
# B2: Match Document1 ID:45, Document2 ID:91, Similarity:0.52
# B2: Match Document1 ID:49, Document2 ID:88, Similarity:1.0
# B2: Match Document1 ID:52, Document2 ID:84, Similarity:1.0
# B2: Match Document1 ID:81, Document2 ID:82, Similarity:0.5
# B2: Match Document1 ID:105, Document2 ID:127, Similarity:0.72
# B2: Match Document1 ID:118, Document2 ID:122, Similarity:1.0
# B2: Match Document1 ID:124, Document2 ID:130, Similarity:0.96
# B2: Match Document1 ID:125, Document2 ID:133, Similarity:1.0
# B2: Match Document1 ID:126, Document2 ID:134, Similarity:1.0
# B2: Match Document1 ID:142, Document2 ID:215, Similarity:0.88
# B2: Match Document1 ID:143, Document2 ID:144, Similarity:0.58
# B2: Match Document1 ID:153, Document2 ID:154, Similarity:1.0
# B2: Match Document1 ID:161, Document2 ID:162, Similarity:0.96
# B2: Match Document1 ID:188, Document2 ID:189, Similarity:1.0
# B2: Match Document1 ID:227, Document2 ID:487, Similarity:0.64
# B2: Match Document1 ID:228, Document2 ID:435, Similarity:1.0
# B2: Match Document1 ID:243, Document2 ID:252, Similarity:1.0
# B2: Match Document1 ID:312, Document2 ID:313, Similarity:1.0
# B2: Match Document1 ID:357, Document2 ID:363, Similarity:0.58
# B2: Match Document1 ID:383, Document2 ID:386, Similarity:1.0
# B2: Match Document1 ID:388, Document2 ID:389, Similarity:1.0
# B2: Match Document1 ID:414, Document2 ID:430, Similarity:0.8
# B2: Match Document1 ID:496, Document2 ID:623, Similarity:1.0
# B2: Match Document1 ID:507, Document2 ID:522, Similarity:0.5
# B2: Match Document1 ID:509, Document2 ID:521, Similarity:0.96
# B2: Match Document1 ID:519, Document2 ID:633, Similarity:1.0
# B2: Match Document1 ID:535, Document2 ID:536, Similarity:1.0
# B2: Match Document1 ID:538, Document2 ID:546, Similarity:0.5
# B2: Match Document1 ID:539, Document2 ID:551, Similarity:1.0
# B2: Match Document1 ID:542, Document2 ID:625, Similarity:1.0
# B2: Match Document1 ID:592, Document2 ID:594, Similarity:1.0
# B2: Match Document1 ID:602, Document2 ID:603, Similarity:1.0
# B2: Match Document1 ID:641, Document2 ID:728, Similarity:0.74
# B2: Match Document1 ID:642, Document2 ID:650, Similarity:0.98
# B2: Match Document1 ID:644, Document2 ID:726, Similarity:1.0
# B2: Match Document1 ID:647, Document2 ID:653, Similarity:1.0
# B2: Match Document1 ID:649, Document2 ID:655, Similarity:1.0
# B2: Match Document1 ID:651, Document2 ID:732, Similarity:0.86
# B2: Match Document1 ID:661, Document2 ID:675, Similarity:0.74
# B2: Match Document1 ID:684, Document2 ID:688, Similarity:1.0
# B2: Match Document1 ID:686, Document2 ID:687, Similarity:1.0
# B2: Match Document1 ID:695, Document2 ID:696, Similarity:0.98
# B2: Match Document1 ID:706, Document2 ID:707, Similarity:0.96
